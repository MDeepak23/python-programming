# %% [markdown]
# #Bollywood Actor Ranking

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv('/content/BollywoodActorRanking.csv')
data
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0                  NaN
# 300      673     Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# ...

# %%
data.head()
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
d = data.sample(5)
d
# Out:
#      actorId           actorName  movieCount  ratingSum  normalizedMovieRank  \
# 219      592          Vijay Raaz          11        240              1.17787
# 98       471       Isha Koppikar          10        400              2.95652
# 247      620         Manoj Joshi           5        140              1.78261
# 154      527  Mithun Chakraborty          23        720              2.10586
# 39       412        Preity Zinta          16        880              4.42391
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 219       71000               1.17973           1.77373
# 98       234000               1.60024           3.02710
# 247           0                   NaN           1.44603
# 154      160000               1.40933           2.43348
# 39       877000               3.25904           4.80881

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   299 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB

# %%
data.describe()
# Out:
#           actorId  movieCount    ratingSum  normalizedMovieRank    googleHits  \
# count  301.000000  301.000000   301.000000           299.000000  3.010000e+02
# mean   523.000000   10.232558   419.136213             2.768970  3.741886e+05
# std     87.035433    8.508764   446.972689             1.626970  6.647169e+05
# min    373.000000    0.000000     0.000000             1.000000  0.000000e+00
# 25%    448.000000    5.000000   140.000000             1.489130  0.000000e+00
# 50%    523.000000    7.000000   260.000000             2.369570  7.640000e+04
# 75%    598.000000   12.000000   500.000000             3.621045  3.850000e+05
# max    673.000000   54.000000  2950.000000            10.000000  3.490000e+06
#
#        normalizedGoogleRank  normalizedRating
# count            189.000000        301.000000
# mean               2.533937          2.933339
# std                1.951501          1.747883
# min                1.000000          1.000000
# ...

# %%
data.isnull().sum()
# Out:
# actorId                   0
# actorName                 0
# movieCount                0
# ratingSum                 0
# normalizedMovieRank       2
# googleHits                0
# normalizedGoogleRank    112
# normalizedRating          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['actorId', 'actorName', 'movieCount', 'ratingSum',
#        'normalizedMovieRank', 'googleHits', 'normalizedGoogleRank',
#        'normalizedRating'],
#       dtype='object')

# %%
data.shape
# Out:
# (301, 8)

# %%
sns.barplot(x='actorName',y='movieCount',data=d)
# Out:
# <Axes: xlabel='actorName', ylabel='movieCount'>

# %% [markdown]
# #OBSERVATION
# Above bar graph represents actorName and movieCount sample.Here Mithun Chakraborthy has more movieCount i.e 23 then followed by Preity zinta with 16 movie count then least moviecount by manoj joshi

# %%
sns.heatmap(data.select_dtypes(include=np.number).corr(), cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# #OBSERVATION
#
# This heatmap shows the correlation between different variables related to actors and their performance metrics, such as movie count, rating sum, normalized ranks, and Google hits. High correlations (in yellow) indicate strong positive relationships, while low correlations (in purple) suggest weak or negative relationships.

# %%
sns.barplot(x='actorName',y='ratingSum',data=d)
# Out:
# <Axes: xlabel='actorName', ylabel='ratingSum'>

# %% [markdown]
# #OBSERVATION
#
# This bar chart shows the sum of ratings for each actor. Preity Zinta has the highest rating sum, followed by Mithun Chakraborty, while Manoj Joshi has the lowest. This indicates variations in their cumulative ratings.
# ```
